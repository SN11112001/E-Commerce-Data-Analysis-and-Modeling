# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 25px; background-color: orange; font-size:100%; text-align:left">
# <p style="font-family:Trebuchet MS; font-weight:bold; letter-spacing: 0px; color:black; font-size:200%; text-align:center;padding: 0px;"> E-Commerce Data Analysis & Modeling.</p></div>

# %% [markdown]
# <div align="center">
#   <img src="https://media.istockphoto.com/id/1266252971/vector/online-shop-logo-design.jpg?s=612x612&w=0&k=20&c=UtXBlVqaijOagZXPDiEZNlDoBRfE8o7RW8Sb1VUdUeg="  alt="Image Description" width="300" height="300">
# </div>

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 15px; background-color: #FAC898; font-size:100%; text-align:left">
#
# <div style="font-family:Trebuchet MS;background-color: #FAC898; padding:30px; font-size:17px">
#
#
# <b>Background :</b><br>
#
# 1. The E-Commerce company offers in-store style and clothing advice sessions. Customers come into the store and have sessions/meetings with a personal stylist; then, they can go home and order the clothes they want.<br>
#
#     <br>
#
# 2. The company offers its purchase service through either its own mobile app or its website.
#
#     <br>
#
#     <br>
#
#
# <b>Problem Statement :</b><br>
#
# 1. The E-Commerce company is willing to understand where to allocate resources and focus efforts on maximizing customer spending, i.e. trying to decide whether to focus their efforts on their mobile app experience or their website.<br>
#
#     <br>
#
#     <br>
#
#
# <b>Project Objective :</b>
#
# 1. Analyze customer spending patterns based on the time spent on the mobile app and the desktop site to determine the impact of each platform on customer expenditures.<br>
#
#     <br>
#
# 2. After Analyzing we need to train a Machine Learning Model which can find the key factors that significantly influence the customer churn or attrition.

# %% [markdown]
# ---

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color:##F0E68C ; font-size:100%; text-align:left">
#
# <div style="font-family:Trebuchet MS;background-color:'#DEB887'; padding:30px; font-size:17px">
#
# <h3 align="left"><font color=orange>📊 Table of Contents:</font></h3><br>
#
#
# 1. <b>Importing Libraries & Dataset.</b><br>
#
#     <br>
# 2. <b>Data Wrangling.</b><br>
#     * Data Cleaning.<br>
#     * Handling Missing Values.<br>
#     * Handling Inconsistances.<br>
#
#     <br>
# 3. <b>Exploratory Data Analysis (EDA)</b><br>
#     * Visualizing Dependent Variable.<br>
#     * Visualizing Independent Variables.<br>
#     * Generating Insights.<br>
#
#     <br>
# 4. <b>Data Preprocessing.</b><br>
#     * Variable Selection and Importance.<br>
#     * Splitting Data for Model Training.<br>
#     * Feature Transformation and Encoding.<br>
#
#     <br>
# 5. <b>Model Creation using "Multiple Linear Regression".</b><br>
#     * Model Training.<br>
#     * Model Evaluation and Performance.<br>
#
#     <br>
# 6. <b>Conclusion.</b><br>
#     * Observations.
#     * Recommendations.

# %% [markdown]
# ---

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 20px; background-color: #FED8B1; font-size:100%; text-align:center">
# <p style="font-family:Trebuchet MS; font-weight:bold; letter-spacing: 0px; color:black; font-size:150%; text-align:center;padding: 0px;">1. Importing Libraries and Dataset.</p></div>

# %% [markdown]
# #### a. Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# #### b. Importing Dataset

# %%
df = pd.read_csv("C:\\Users\\Laptopmajha\\Desktop\\Projects\\Python\\E-Commerce Data Analysis and Modeling\\Dataset.csv")

df.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address  Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605    Teal
# 1     4547 Archer Common\nDiazchester, CA 06566-8576    Cyal
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...    Cyal
# 3   1414 David Throughway\nPort Jason, OH 22070-1220  Bisque
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...    Aqua
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# ...

# %%
for i in df.columns:
    print(f"{i} - {df[i].dtype}")
# Out:
# Email - object
# Address - object
# Avatar - object
# Avg. Session Length - float64
# Time on App - float64
# Time on Website - float64
# Length of Membership - float64
# Yearly Amount Spent - float64

# %% [markdown]
# <div style="border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=orange>📊 Inference:</font></h3><br>
#
#
# 1. **Email:** It is the unique identifier for each record and does not contribute directly to the analysis.<br>
#     <br>
# 2. **Address:** It can be used to track and differentiate groups of customers within the dataset.<br>
#     <br>
# 3. **Avatar:** It is a virtual identity character given to customers based on their credit score and thus can be used to identify potential purchases they can make.<br>
#     <br>
# 4. **Avg. Session Length:** It is a numerical value that measures the total duration (in minutes) customer spent before making the purchase.<br>
#     <br>
# 5. **Time on App:** It is a numerical value that measures the total time spent on the App by the customer before making the purchase.<br>
#     <br>
# 6. **Time on Website:** It is a numerical value that measures the total time spent on the Website by the customer before making the purchase..<br>
#     <br>
# 7. **Length of Membership:** It is a numerical value that represents the total years the customer has been with the company. This can be used to test the company's return customer rate and Customer Lifetime Value.<br>
#     <br>
# 8. **Yearly Amount Spent:** It is the dependent numerical value tells us the total amount a specific customer has spent yearly on the platform.

# %% [markdown]
# ---

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 20px; background-color: #FED8B1; font-size:100%; text-align:left">
# <p style="font-family:Trebuchet MS; font-weight:bold; letter-spacing: 0px; color:black; font-size:150%; text-align:center;padding: 0px;">2. Data Wrangling.</p></div>

# %% [markdown]
# #### a. Checking the Dimensions of Dataset.

# %%
print()

print("Total records/rows:",df.shape[0])

print()

print("Total attributes/columns:",df.shape[1])
# Out:
# Total records/rows: 500
#
# Total attributes/columns: 8

# %% [markdown]
# #### b. Checking column datatypes and total null Values present in Dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %% [markdown]
# #### c. Dropping Insignificant Features.

# %%
df = df.drop(labels = ["Email","Address"], axis = 1)

# %% [markdown]
# #### b. Renaming Columns.

# %%
df.rename(columns = {"Avg. Session Length" : "Average Session Length", "Yearly Amount Spent" : "Annual Amount Spent"},
          inplace = True)

# %% [markdown]
# #### 2. Checking for the Duplicate Records (if any).

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Avatar, Average Session Length, Time on App, Time on Website, Length of Membership, Annual Amount Spent]
# Index: []

# %% [markdown]
# #### 3. Performing Descriptive Statistical Analysis on Categorical Columns.

# %%
df.describe(include = "object").T
# Out:
#        count unique   top freq
# Avatar   500      5  Aqua  109

# %% [markdown]
# #### 4. Checking the final dataset again.

# %%
df
# Out:
#      Avatar  Average Session Length  Time on App  Time on Website  \
# 0      Teal               34.497268    12.655651        39.577668
# 1      Cyal               31.926272    11.109461        37.268959
# 2      Cyal               33.000915    11.330278        37.110597
# 3    Bisque               34.305557    13.717514        36.721283
# 4      Aqua               33.330673    12.795189        37.536653
# ..      ...                     ...          ...              ...
# 495   Wheat               33.237660    13.566160        36.417985
# 496    Cyal               34.702529    11.695736        37.190268
# 497  Bisque               32.646777    11.499409        38.332576
# 498  Bisque               33.322501    12.391423        36.840086
# 499   Wheat               33.715981    12.418808        35.771016
#
#      Length of Membership  Annual Amount Spent
# 0                4.082621           587.951054
# 1                2.664034           392.204933
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Avatar                  500 non-null    object
#  1   Average Session Length  500 non-null    float64
#  2   Time on App             500 non-null    float64
#  3   Time on Website         500 non-null    float64
#  4   Length of Membership    500 non-null    float64
#  5   Annual Amount Spent     500 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 23.6+ KB

# %% [markdown]
# <div style="font-family:Trebuchet MS;border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=orange>📊 Inference:</font></h3><br>
#
#
# 1. In Dataset, we have total of **500 records** and **7 features**, in which we have **0 "null"** values. <br>
#     <br>
# 2. The columns **"Email"** and **"Address"** have **very high cardinality**. Thus those should not be used for model training and thus removed.<br>
#     <br>
# 3. None of the records have duplicates.<br>
#     <br>
# 3. The column **"Avatar"** has only 5 cardinalities, thus can be a significant factor and used for model building.<br>

# %% [markdown]
# ---

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 20px; background-color: #FED8B1; font-size:100%; text-align:left">
# <p style="font-family:Trebuchet MS; font-weight:bold; letter-spacing: 0px; color:black; font-size:150%; text-align:center;padding: 0px;">3. Exploratory Data Analysis.</p></div>

# %%
df.describe(include = "object").T
# Out:
#        count unique   top freq
# Avatar   500      5  Aqua  109

# %%
df.describe(include = "float").T
# Out:
#                         count        mean        std         min         25%  \
# Average Session Length  500.0   33.053194   0.992563   29.532429   32.341822
# Time on App             500.0   12.052488   0.994216    8.508152   11.388153
# Time on Website         500.0   37.060445   1.010489   33.913847   36.349257
# Length of Membership    500.0    3.533462   0.999278    0.269901    2.930450
# Annual Amount Spent     500.0  499.314038  79.314782  256.670582  445.038277
#
#                                50%         75%         max
# Average Session Length   33.082008   33.711985   36.139662
# Time on App              11.983231   12.753850   15.126994
# Time on Website          37.069367   37.716432   40.005182
# Length of Membership      3.533975    4.126502    6.922689
# Annual Amount Spent     498.887875  549.313828  765.518462

# %% [markdown]
# ### a. Univariate Analysis.

# %% [markdown]
# #### I. 'Avatar' Column.

# %%
Avatar_Count = df.groupby("Avatar").agg(Total_Count = ("Avatar","count")).sort_values("Total_Count")

Avatar_Count
# Out:
#         Total_Count
# Avatar
# Bisque           88
# Wheat            95
# Teal            100
# Cyal            108
# Aqua            109

# %%
print()

plt.figure()

sns.barplot(x = Avatar_Count["Total_Count"][::-1],
           y = Avatar_Count.index[::-1],
            color = "#FFA500")

sns.despine()

plt.show()

# %% [markdown]
# #### II. 'Average Session Length' Column.

# %%
sns.histplot(data = df["Average Session Length"], kde = True, color = "#FFA500")

plt.show()

# %%
sns.boxplot(y = df["Average Session Length"], color = "#FFA500")
# Out:
# <AxesSubplot:ylabel='Average Session Length'>

# %% [markdown]
# #### III. 'Time on App' Column.

# %%
sns.histplot(data = df["Time on App"], kde = True, color = "#FFA500")

plt.show()

# %%
sns.boxplot(y = df["Time on App"], color = "#FFA500")
# Out:
# <AxesSubplot:ylabel='Time on App'>

# %% [markdown]
# #### IV. 'Time on Website' Column.

# %%
sns.histplot(data = df["Time on Website"], kde = True, color = "#FFA500")

plt.show()

# %%
sns.boxplot(y = df["Time on Website"], color = "#FFA500")
# Out:
# <AxesSubplot:ylabel='Time on Website'>

# %% [markdown]
# #### V. 'Length of Membership' Column.

# %%
sns.histplot(data = df["Length of Membership"], kde = True, color = "#FFA500")

plt.show()

# %%
sns.boxplot(y = df["Length of Membership"], color = "#FFA500")
# Out:
# <AxesSubplot:ylabel='Length of Membership'>

# %% [markdown]
# #### VI. 'Annual Amount Spent' Column.

# %%
sns.histplot(data = df["Annual Amount Spent"], kde = True, color = "#FFA500")

plt.show()

# %%
sns.boxplot(y = df["Annual Amount Spent"], color = "#FFA500")
# Out:
# <AxesSubplot:ylabel='Annual Amount Spent'>

# %% [markdown]
# ### a. Bivariate Analysis.

# %% [markdown]
# #### I. Checking the relationship between "Time on App" and "Total Amount Spent".

# %%
sns.scatterplot(x = df["Time on App"],
               y = df["Annual Amount Spent"])

sns.despine()
                
plt.show()

# %% [markdown]
# #### II. Checking the relationship between "Time on Website" and "Total Amount Spent".

# %%
sns.scatterplot(x = df["Time on Website"],
               y = df["Annual Amount Spent"])

sns.despine()
                
plt.show()

# %% [markdown]
# #### III. Checking the relationship between "Length of Membership" and "Total Amount Spent".

# %%
sns.scatterplot(x = df["Length of Membership"],
               y = df["Annual Amount Spent"])

sns.despine()
                
plt.show()

# %% [markdown]
# #### IV. Cheking the correlation between Independent variables and Dependent variables.

# %%
df.corr()
# Out:
#                         Average Session Length  Time on App  Time on Website  \
# Average Session Length                1.000000    -0.027826        -0.034987
# Time on App                          -0.027826     1.000000         0.082388
# Time on Website                      -0.034987     0.082388         1.000000
# Length of Membership                  0.060247     0.029143        -0.047582
# Annual Amount Spent                   0.355088     0.499328        -0.002641
#
#                         Length of Membership  Annual Amount Spent
# Average Session Length              0.060247             0.355088
# Time on App                         0.029143             0.499328
# Time on Website                    -0.047582            -0.002641
# Length of Membership                1.000000             0.809084
# Annual Amount Spent                 0.809084             1.000000

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div style="font-family:Trebuchet MS; border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=orange>📊 Inference:</font></h3><br>
#
#
# 1. Almost, all the numerical features are normally distributed with their mean.<br>
#     <br>
# 2. While, almost ever other featured had few outliers, which may be removed if the model performance is not good.<br>
#     <br>
# 3. All the features in our dataset are positively correlated with dependent variable, except the important feature "Time on Website". Still, we will have to keep it, in order to, calculate its influence on Output variable.<br>
#     <br>
# 3. None of the features are internally correlated. Thus, no need to remove any feature.<br>

# %% [markdown]
# ---

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 20px; background-color: #FED8B1; font-size:100%; text-align:left">
# <p style="font-family:Trebuchet MS; font-weight:bold; letter-spacing: 0px; color:black; font-size:150%; text-align:center;padding: 0px;">4. Data Preprocessing.</p></div>

# %%
X = df.iloc[:,:-1]

X
# Out:
#      Avatar  Average Session Length  Time on App  Time on Website  \
# 0      Teal               34.497268    12.655651        39.577668
# 1      Cyal               31.926272    11.109461        37.268959
# 2      Cyal               33.000915    11.330278        37.110597
# 3    Bisque               34.305557    13.717514        36.721283
# 4      Aqua               33.330673    12.795189        37.536653
# ..      ...                     ...          ...              ...
# 495   Wheat               33.237660    13.566160        36.417985
# 496    Cyal               34.702529    11.695736        37.190268
# 497  Bisque               32.646777    11.499409        38.332576
# 498  Bisque               33.322501    12.391423        36.840086
# 499   Wheat               33.715981    12.418808        35.771016
#
#      Length of Membership
# 0                4.082621
# 1                2.664034
# 2                4.104543
# 3                3.120179
# 4                4.446308
# ...

# %%
y = df.iloc[:,-1]

y
# Out:
# 0      587.951054
# 1      392.204933
# 2      487.547505
# 3      581.852344
# 4      599.406092
#           ...
# 495    573.847438
# 496    529.049004
# 497    551.620146
# 498    456.469510
# 499    497.778642
# Name: Annual Amount Spent, Length: 500, dtype: float64

# %% [markdown]
# #### a. Performing One Hot Encoding on Categorical Features.

# %%
X = pd.get_dummies(data = X, columns = ["Avatar"])

X
# Out:
#      Average Session Length  Time on App  Time on Website  \
# 0                 34.497268    12.655651        39.577668
# 1                 31.926272    11.109461        37.268959
# 2                 33.000915    11.330278        37.110597
# 3                 34.305557    13.717514        36.721283
# 4                 33.330673    12.795189        37.536653
# ..                      ...          ...              ...
# 495               33.237660    13.566160        36.417985
# 496               34.702529    11.695736        37.190268
# 497               32.646777    11.499409        38.332576
# 498               33.322501    12.391423        36.840086
# 499               33.715981    12.418808        35.771016
#
#      Length of Membership  Avatar_Aqua  Avatar_Bisque  Avatar_Cyal  \
# 0                4.082621            0              0            0
# 1                2.664034            0              0            1
# ...

# %% [markdown]
# Splitting data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# <div style="font-family:Trebuchet MS; border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=orange>📊 Inference:</font></h3><br>
#
#
# 1. "One Hot Encoding" is performed on the categorical column "Avatar", adding 5 more columns to the training dataset.<br>
#     <br>
# 3. The dataset is seperated into Dependent Set and Independent Set, and further splitted into 80% training and rest 20% as testing set, using train_test_split.<br>

# %% [markdown]
# ---

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 20px; background-color: #FED8B1; font-size:100%; text-align:left">
# <p style="font-family:Trebuchet MS; font-weight:bold; letter-spacing: 0px; color:black; font-size:150%; text-align:center;padding: 0px;">5. Model Creation using "Multiple Linear Regression".</p></div>

# %% [markdown]
# #### a. Fitting the Model with data.

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# #### b. Predicting the values with model.

# %%
y_pred
# Out:
# array([439.97534262, 491.22933745, 371.60957955, 512.91488945,
#        497.39365389, 448.98629019, 457.7701792 , 335.60618321,
#        528.34284056, 662.32968251, 557.43279579, 527.71291098,
#        553.60288354, 458.98320372, 448.96511364, 433.05003085,
#        563.32009833, 406.37911185, 597.40514305, 485.77833857,
#        714.41575626, 498.39163128, 411.36199805, 554.46612776,
#        553.29918578, 398.29982363, 420.9558596 , 395.14430634,
#        550.08609155, 465.21296859, 557.26862373, 507.15954995,
#        507.49496718, 462.90228843, 424.30375449, 399.01965656,
#        505.03700589, 431.92548858, 569.53609485, 423.41949554,
#        486.32321262, 603.83956998, 616.2768408 , 588.43410249,
#        451.36562394, 378.95995839, 555.89025901, 462.36405889,
#        501.18222869, 399.47147068, 523.56976953, 416.73819929,
#        576.77782435, 477.32873112, 456.03370104, 399.63246741,
#        563.86942872, 306.70482432, 561.47138855, 474.46119072,
# ...

# %% [markdown]
# #### c. Getting the intercept and slope values for the final equation of modal.

# %%
regressor.intercept_
# Out:
# -1057.062158811165

# %%
regressor.coef_
# Out:
# array([25.81585998, 38.77857288,  0.46566743, 61.83878239,  1.5748091 ,
#         1.65630238, -1.08665413, -2.01051498, -0.13394237])

# %% [markdown]
# #### d. Getting the Equation with the features name.

# %%
string = "Annual Amount Spent = "

for i in range(len(X.columns)):
    string = string + "(" + str(round(regressor.coef_[i],2)) + " " + X.columns[i] + ")" + " + "
    
string
# Out:
# 'Annual Amount Spent = (25.82 Average Session Length) + (38.78 Time on App) + (0.47 Time on Website) + (61.84 Length of Membership) + (1.57 Avatar_Aqua) + (1.66 Avatar_Bisque) + (-1.09 Avatar_Cyal) + (-2.01 Avatar_Teal) + (-0.13 Avatar_Wheat) + '

# %% [markdown]
# #### e. Measuring Performace Metrics

# %%
score=r2_score(y_test,y_pred)

print("R Squared:", score)
# Out:
# R Squared: 0.9855669650291478

# %%
mse = mean_squared_error(y_test, y_pred)

print("Mean Squared Error (MSE):", mse)
# Out:
# Mean Squared Error (MSE): 97.09787721476556

# %%
rmse = mean_squared_error(y_test, y_pred, squared=False)

print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Root Mean Squared Error (RMSE): 9.853825511686594

# %%
mae = mean_absolute_error(y_test, y_pred)

print("Mean Absolute Error (MAE):", mae)
# Out:
# Mean Absolute Error (MAE): 7.798508411261537

# %% [markdown]
# #### f. Plotting the model predicted values along side actual values.

# %%
plt.figure()

plt.scatter(y_test, y_pred)

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <div style="border-radius:10px; border:black solid; padding: 20px; background-color: #FED8B1; font-size:100%; text-align:left">
# <p style="font-family:Trebuchet MS; font-weight:bold; letter-spacing: 0px; color:black; font-size:150%; text-align:center;padding: 0px;">5. Conclusion.</p></div>

# %% [markdown]
# <div style="font-family:Trebuchet MS; border-radius:10px; border:#808080 solid; padding: 15px; background-color: ##F0E68C ; font-size:100%; text-align:left">
#
# <h3 align="left"><font color=orange>📊 Obervations</font></h3>
#
#
# * The order of importance of influence (from highest to lowest) of features on the total amount spent by customers is as follows :-
#
#    i. Length of Membership <br>
#    ii. Time on App <br>
#    iii. Average Session Length <br>
#    iv. Time on Website <br>
#
#
# * The model performs well since the performance metric "r-squared" shows excellent values, i.e. 0.98. That means the model can predict the values with all the features used in model training.<br>
#
#     <br>
#
# * The equation for the model is as follows :-
#
#     'Annual Amount Spent = (25.82 Average Session Length) + (38.78 Time on App) + (0.47 Time on Website) + (61.84 Length of Membership) + (1.57 Avatar_Aqua) + (1.66 Avatar_Bisque) + (-1.09 Avatar_Cyal) + (-2.01 Avatar_Teal) + (-0.13 Avatar_Wheat)
#
# <h3 align="left"><font color=orange>📊 Recommendations</font></h3>
#
# 1. To solve the problem, the company should start focusing on its app since it is the second most crucial factor leading to annual customer purchases, unlike the website. Customers prefer apps more than websites. Thus, the company can focus their efforts on their mobile app experience.<br>
#
#     <br>
#
# 2. The highest contributing factor, "Length of Membership", clearly shows our scheme is making our customers spend more money. Thus, the same can be further promoted using more and better offer deals.<br>
#
#     <br>
#
# 3. With the above data, it is undoubtedly proved that the higher the customer session time, the more likely the customer is to spend money. Thus, we can make our apps and websites more engaging content.<br>
#
#     <br>
#
# 4.  The "Avatar" feature may not directly contribute to increasing sales, but the same can be used to improve both our app and website experience. It should be taken as the highest priority since it is nowhere contributing to customer purchases and thus is a red sign.
